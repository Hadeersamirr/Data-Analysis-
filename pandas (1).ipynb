# %%
import pandas as pd
weather_data ={
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Sunny', 'Sunny']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
newdf = df[1:]
newdf
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf = df.iloc[2:5 , :-2]
newdf
# Out:
#         day  temperature
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.index[df.day== "1/4/2017"][0]
# Out:
# 3

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
startindex = int(df.index[df.day =="1/4/2017"][0])
type(startindex)
# Out:
# int

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
startindex
# Out:
# 3

# %%
df[startindex : startindex+2]
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny

# %%
print(df.columns)
columnsNames= df.columns.to_list()
print(columnsNames)
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')
# ['day', 'temperature', 'windspeed', 'event']

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4    Sunny
# 5    Sunny
# Name: event, dtype: object

# %%
eventlist = df.event.to_list()
eventlist
# Out:
# ['Rain', 'Sunny', 'Snow', 'Snow', 'Sunny', 'Sunny']

# %%
twodf = df[['day' , 'event']]
twodf
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017  Sunny
# 5  1/6/2017  Sunny

# %%
df[["day","event"]]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017  Sunny
# 5  1/6/2017  Sunny

# %%
print(df.temperature.mean())
print(df['temperature'].std())
# Out:
# 30.333333333333332
# 3.8297084310253524

# %%
len(df[df['temperature']>30])
# Out:
# 4

# %%
df['day'][df['temperature'] == df['temperature'].min()]
# Out:
# 3    1/4/2017
# Name: day, dtype: object

# %%
data = df.temperature.sort_values()
data
# Out:
# 3    24
# 2    28
# 5    31
# 0    32
# 4    32
# 1    35
# Name: temperature, dtype: int64

# %%
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df['event'].max()
# Out:
# 'Sunny'

# %%
df.event.value_counts()
# Out:
# Sunny    3
# Snow     2
# Rain     1
# Name: event, dtype: int64

# %%
df.event.value_counts().index[0]
# Out:
# 'Sunny'

# %%
df.event.value_counts()[0]
# Out:
# 3

# %%
print("Max event:" + df.event.value_counts().index[0] + "and it occured" )
# Out:
# Max event:Sunnyand it occured

# %%
df.set_index("day",inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 3)

# %%
df['day'][df['temperature'] == df['temperature'].min()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-83d0b24c89a0> in <cell line: 1>()
# ----> 1 df['day'][df['temperature'] == df['temperature'].min()]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'day'

# %%
df.loc["1/1/2017" : "1/4/2017"]
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow

# %%
df.shape
# Out:
# (6, 3)

# %%
df.reset_index(inplace=True )
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf = df.copy()
newdf.set_index("day" , inplace=True)

# %%
newdf
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf
